# %%
# NSW conservation List

# %%
import urllib.request, json
import pandas as pd

# %%
# top level directory
projectdir = "/Users/oco115/PycharmProjects/auth-lists-updates/NSW-2022-10/"

with urllib.request.urlopen("https://data.bionet.nsw.gov.au/biosvcapp/odata/SpeciesNames") as url:
    data = json.loads(url.read().decode())

# %%
# normalize data
data = pd.json_normalize(data, record_path =['value'])

# %%
data
# Out:
#                                  dcterms_rightsHolder dcterms_rights  \
# 0      NSW Dept of Planning, Industry and Environment      CC-BY 4.0
# 1      NSW Dept of Planning, Industry and Environment      CC-BY 4.0
# 2      NSW Dept of Planning, Industry and Environment      CC-BY 4.0
# 3      NSW Dept of Planning, Industry and Environment      CC-BY 4.0
# 4      NSW Dept of Planning, Industry and Environment      CC-BY 4.0
# ...                                               ...            ...
# 23248  NSW Dept of Planning, Industry and Environment      CC-BY 4.0
# 23249  NSW Dept of Planning, Industry and Environment      CC-BY 4.0
# 23250  NSW Dept of Planning, Industry and Environment      CC-BY 4.0
# 23251  NSW Dept of Planning, Industry and Environment      CC-BY 4.0
# 23252  NSW Dept of Planning, Industry and Environment      CC-BY 4.0
#
#       dcterms_language dcterms_type               dcterms_modified  \
# 0                   en      service   2013-12-20T15:06:07.13+11:00
# 1                   en      service      2006-01-30T17:20:32+11:00
# 2                   en      service      2006-11-23T16:57:26+11:00
# 3                   en      service      2006-01-30T17:20:32+11:00
# 4                   en      service   2021-02-01T18:14:41.78+11:00
# ...                ...          ...                            ...
# 23248               en      service  2022-08-08T20:40:25.177+10:00
# 23249               en      service  2022-08-11T09:52:48.803+10:00
# 23250               en      service      2022-08-31T14:06:19+10:00
# 23251               en      service   2022-08-31T14:17:04.81+10:00
# 23252               en      service  2022-09-07T21:43:50.623+10:00
#
#                    dcterms_available  speciesID   taxonRank  kingdomID  \
# 0          1995-12-15T12:48:13+11:00          1     Species        138
# 1          1995-12-15T12:48:13+11:00          2     Species        138
# 2          1995-12-15T12:48:14+11:00          3     Species        138
# 3          1995-12-15T12:48:14+11:00          4     Species        138
# 4          1995-12-15T12:48:14+11:00          5     Species        138
# ...                              ...        ...         ...        ...
# 23248  2022-08-08T20:40:25.177+10:00      24408     Species        139
# 23249  2022-08-11T09:47:09.447+10:00      24411  Subspecies        138
# 23250  2022-08-31T13:56:07.913+10:00      24412     Species        138
# 23251   2022-08-31T14:17:04.81+10:00      24414     Species        138
# 23252  2022-09-07T21:43:50.623+10:00      24415     Species        139
#
#         kingdom  ...      stateConservation protectedInNSW  sensitivityClass  \
# 0      Animalia  ...             Vulnerable           true     Not Sensitive
# 1      Animalia  ...             Not Listed           true     Not Sensitive
# 2      Animalia  ...             Not Listed           true     Not Sensitive
# 3      Animalia  ...             Not Listed           true     Not Sensitive
# 4      Animalia  ...             Not Listed           true     Not Sensitive
# ...         ...  ...                    ...            ...               ...
# 23248   Plantae  ...             Not Listed          false     Not Sensitive
# 23249  Animalia  ...             Endangered          false     Not Sensitive
# 23250  Animalia  ...  Critically Endangered          false     Not Sensitive
# 23251  Animalia  ...             Not Listed          false     Not Sensitive
# 23252   Plantae  ...             Not Listed          false     Not Sensitive
#
#       TSProfileID  countryConservation highThreatWeed  \
# 0         10211.0           Vulnerable           None
# 1             NaN           Not Listed           None
# 2             NaN           Not Listed           None
# 3             NaN           Not Listed           None
# 4             NaN           Not Listed           None
# ...           ...                  ...            ...
# 23248         NaN           Not Listed           None
# 23249     20422.0           Not Listed           None
# 23250     20424.0           Not Listed           None
# 23251         NaN           Not Listed           None
# 23252         NaN           Not Listed           None
#
#        widelyCultivatedNativeSpecies  CAMBA  JAMBA  ROKAMBA
# 0                               None  false  false    false
# 1                               None  false  false    false
# 2                               None  false  false    false
# 3                               None  false  false    false
# 4                               None  false  false    false
# ...                              ...    ...    ...      ...
# 23248                           None  false  false    false
# 23249                           None  false  false    false
# 23250                           None  false  false    false
# 23251                           None  false  false    false
# 23252                           None  false  false    false
#
# [23253 rows x 51 columns]

# %%
# Start processing
df = data[data.stateConservation != 'Not Listed']

# %%
df
# Out:
#                                  dcterms_rightsHolder dcterms_rights  \
# 0      NSW Dept of Planning, Industry and Environment      CC-BY 4.0
# 5      NSW Dept of Planning, Industry and Environment      CC-BY 4.0
# 30     NSW Dept of Planning, Industry and Environment      CC-BY 4.0
# 31     NSW Dept of Planning, Industry and Environment      CC-BY 4.0
# 32     NSW Dept of Planning, Industry and Environment      CC-BY 4.0
# ...                                               ...            ...
# 23153  NSW Dept of Planning, Industry and Environment      CC-BY 4.0
# 23164  NSW Dept of Planning, Industry and Environment      CC-BY 4.0
# 23177  NSW Dept of Planning, Industry and Environment      CC-BY 4.0
# 23249  NSW Dept of Planning, Industry and Environment      CC-BY 4.0
# 23250  NSW Dept of Planning, Industry and Environment      CC-BY 4.0
#
#       dcterms_language dcterms_type               dcterms_modified  \
# 0                   en      service   2013-12-20T15:06:07.13+11:00
# 5                   en      service   2022-05-12T15:50:01.01+10:00
# 30                  en      service  2015-05-28T10:14:29.083+10:00
# 31                  en      service   2016-06-09T16:48:09.44+10:00
# 32                  en      service      2011-11-11T11:23:05+11:00
# ...                ...          ...                            ...
# 23153               en      service   2022-01-21T11:28:03.99+11:00
# 23164               en      service  2017-10-04T17:44:03.637+11:00
# 23177               en      service   2017-10-04T17:27:20.77+11:00
# 23249               en      service  2022-08-11T09:52:48.803+10:00
# 23250               en      service      2022-08-31T14:06:19+10:00
#
#                    dcterms_available  speciesID   taxonRank  kingdomID  \
# 0          1995-12-15T12:48:13+11:00          1     Species        138
# 5          1995-12-15T12:48:15+11:00          6     Species        138
# 30         1995-12-15T12:48:23+11:00         31     Species        138
# 31         2010-01-06T11:42:13+11:00         32     Species        138
# 32         1995-12-15T12:48:24+11:00         33     Species        138
# ...                              ...        ...         ...        ...
# 23153   2022-01-21T11:19:35.52+11:00      24292     Species        139
# 23164      1995-12-15T13:43:31+11:00      24313     Species        139
# 23177  2015-03-20T11:28:25.933+11:00      24329     Species        139
# 23249  2022-08-11T09:47:09.447+10:00      24411  Subspecies        138
# 23250  2022-08-31T13:56:07.913+10:00      24412     Species        138
#
#         kingdom  ...      stateConservation protectedInNSW  sensitivityClass  \
# 0      Animalia  ...             Vulnerable           true     Not Sensitive
# 5      Animalia  ...             Vulnerable           true        Category 3
# 30     Animalia  ...             Vulnerable           true     Not Sensitive
# 31     Animalia  ...             Vulnerable           true     Not Sensitive
# 32     Animalia  ...             Endangered           true     Not Sensitive
# ...         ...  ...                    ...            ...               ...
# 23153   Plantae  ...  Critically Endangered          false     Not Sensitive
# 23164   Plantae  ...             Endangered          false        Category 3
# 23177   Plantae  ...             Vulnerable          false     Not Sensitive
# 23249  Animalia  ...             Endangered          false     Not Sensitive
# 23250  Animalia  ...  Critically Endangered          false     Not Sensitive
#
#       TSProfileID  countryConservation highThreatWeed  \
# 0         10211.0           Vulnerable           None
# 5         10975.0           Endangered           None
# 30        10117.0           Not Listed           None
# 31        10212.0           Not Listed           None
# 32        10484.0           Endangered           None
# ...           ...                  ...            ...
# 23153     20378.0           Not Listed           None
# 23164     10636.0           Not Listed           None
# 23177     10735.0           Vulnerable           None
# 23249     20422.0           Not Listed           None
# 23250     20424.0           Not Listed           None
#
#        widelyCultivatedNativeSpecies  CAMBA  JAMBA  ROKAMBA
# 0                               None  false  false    false
# 5                               None  false  false    false
# 30                              None  false  false    false
# 31                              None  false  false    false
# 32                              None  false  false    false
# ...                              ...    ...    ...      ...
# 23153                           None  false  false    false
# 23164                           None  false  false    false
# 23177                           None  false  false    false
# 23249                           None  false  false    false
# 23250                           None  false  false    false
#
# [1532 rows x 51 columns]

# %%
conservation = df[(df['speciesID'] == df['taxonID'])]
conservation = conservation[['taxonRank', 'kingdom' ,'class','order','family','genus','scientificName','specificEpithet','vernacularName','establishmentMeans','stateConservation','protectedInNSW','sensitivityClass','TSProfileID','countryConservation','dcterms_modified','speciesID','taxonID']]
conservation['status'] = conservation['stateConservation']
conservation = conservation.rename(columns={"stateConservation": "sourceStatus"})
conservation = conservation.rename(columns={"TSProfileID": "tsprofileid"})

# %%
conservation
# Out:
#                                  dcterms_rightsHolder dcterms_rights  \
# 0      NSW Dept of Planning, Industry and Environment      CC-BY 4.0
# 5      NSW Dept of Planning, Industry and Environment      CC-BY 4.0
# 30     NSW Dept of Planning, Industry and Environment      CC-BY 4.0
# 32     NSW Dept of Planning, Industry and Environment      CC-BY 4.0
# 51     NSW Dept of Planning, Industry and Environment      CC-BY 4.0
# ...                                               ...            ...
# 23146  NSW Dept of Planning, Industry and Environment      CC-BY 4.0
# 23147  NSW Dept of Planning, Industry and Environment      CC-BY 4.0
# 23153  NSW Dept of Planning, Industry and Environment      CC-BY 4.0
# 23249  NSW Dept of Planning, Industry and Environment      CC-BY 4.0
# 23250  NSW Dept of Planning, Industry and Environment      CC-BY 4.0
#
#       dcterms_language dcterms_type               dcterms_modified  \
# 0                   en      service   2013-12-20T15:06:07.13+11:00
# 5                   en      service   2022-05-12T15:50:01.01+10:00
# 30                  en      service  2015-05-28T10:14:29.083+10:00
# 32                  en      service      2011-11-11T11:23:05+11:00
# 51                  en      service      2011-11-11T11:23:09+11:00
# ...                ...          ...                            ...
# 23146               en      service   2021-10-15T10:15:24.41+11:00
# 23147               en      service  2021-10-22T14:59:20.563+11:00
# 23153               en      service   2022-01-21T11:28:03.99+11:00
# 23249               en      service  2022-08-11T09:52:48.803+10:00
# 23250               en      service      2022-08-31T14:06:19+10:00
#
#                    dcterms_available  speciesID   taxonRank  kingdomID  \
# 0          1995-12-15T12:48:13+11:00          1     Species        138
# 5          1995-12-15T12:48:15+11:00          6     Species        138
# 30         1995-12-15T12:48:23+11:00         31     Species        138
# 32         1995-12-15T12:48:24+11:00         33     Species        138
# 51         1995-12-15T12:48:31+11:00         53     Species        138
# ...                              ...        ...         ...        ...
# 23146  2021-10-15T10:14:05.907+11:00      24283     Species        139
# 23147  2021-10-22T14:46:17.603+11:00      24284     Species        139
# 23153   2022-01-21T11:19:35.52+11:00      24292     Species        139
# 23249  2022-08-11T09:47:09.447+10:00      24411  Subspecies        138
# 23250  2022-08-31T13:56:07.913+10:00      24412     Species        138
#
#         kingdom  ...      stateConservation protectedInNSW  sensitivityClass  \
# 0      Animalia  ...             Vulnerable           True     Not Sensitive
# 5      Animalia  ...             Vulnerable           True        Category 3
# 30     Animalia  ...             Vulnerable           True     Not Sensitive
# 32     Animalia  ...             Endangered           True     Not Sensitive
# 51     Animalia  ...  Critically Endangered           True     Not Sensitive
# ...         ...  ...                    ...            ...               ...
# 23146   Plantae  ...  Critically Endangered          False     Not Sensitive
# 23147   Plantae  ...             Endangered          False     Not Sensitive
# 23153   Plantae  ...  Critically Endangered          False     Not Sensitive
# 23249  Animalia  ...             Endangered          False     Not Sensitive
# 23250  Animalia  ...  Critically Endangered          False     Not Sensitive
#
#       TSProfileID    countryConservation highThreatWeed  \
# 0         10211.0             Vulnerable            NaN
# 5         10975.0             Endangered            NaN
# 30        10117.0             Not Listed            NaN
# 32        10484.0             Endangered            NaN
# 51        10841.0  Critically Endangered            NaN
# ...           ...                    ...            ...
# 23146     20376.0             Not Listed            NaN
# 23147     10521.0             Endangered            NaN
# 23153     20378.0             Not Listed            NaN
# 23249     20422.0             Not Listed            NaN
# 23250     20424.0             Not Listed            NaN
#
#        widelyCultivatedNativeSpecies  CAMBA  JAMBA  ROKAMBA
# 0                                NaN  False  False    False
# 5                                NaN  False  False    False
# 30                               NaN  False  False    False
# 32                               NaN  False  False    False
# 51                               NaN  False  False    False
# ...                              ...    ...    ...      ...
# 23146                            NaN  False  False    False
# 23147                            NaN  False  False    False
# 23153                            NaN  False  False    False
# 23249                            NaN  False  False    False
# 23250                            NaN  False  False    False
#
# [1022 rows x 51 columns]

# %%
#Write to CSV
print("Writing to CSV")
conservation.to_csv(projectdir + "current-lists/conservation-lists/NSW-conservation-2022-10.csv",encoding="UTF-8",index=False)
print('Finished processing')
