# %%
#import essential libraries 
import pandas as pd
import numpy as np
import dateutil.parser as parser
import json as json

# %%
# requires openpyxl version 2.4.0+

from openpyxl import load_workbook
wb = load_workbook(filename='/Users/cha801/Documents/UpdateLists/EPBCActListofThreatened-Flora.xlsx')
ws = wb['Sheet1'] # ws is now an IterableWorksheet


for cell in ws['A:A']:
    #print('Printing from ' + str(cell.column) + str(cell.row))
    ws.cell(row=cell.row, column=5, value=cell.value) 
    
# iterate thru all cells and if hyperlink found attempt modification of cell
for row in ws.rows:
    for cell in row:
        try:
            if len(cell.hyperlink.target)  > 0:
                cell.value = "".join([cell.hyperlink.target])
                # Join cell.value and hyperlink target into string (optionally just assign the hyperlink.target to the cell.value
        except:
            pass

# save workbook to temp .xlsx (I could not manage to read from buffer...) .
wb.save("/Users/cha801/Documents/UpdateLists/v1/EPBCActListofThreatened-Flora.xlsx")

# read with pandas 
data = pd.read_excel("/Users/cha801/Documents/UpdateLists/EPBCActListofThreatened-Flora.xlsx")

# %%
data = pd.read_excel('/Users/cha801/Documents/UpdateLists/v1/EPBCActListofThreatened-Flora.xlsx')
data
# Out:
#                 Genus, species (subspecies, population)    Common Name  \
# 0     https://www.environment.gov.au/cgi-bin/sprat/p...            NaN
# 1     https://www.environment.gov.au/cgi-bin/sprat/p...  Diels' Wattle
# 2     https://www.environment.gov.au/cgi-bin/sprat/p...            NaN
# 3     https://www.environment.gov.au/cgi-bin/sprat/p...            NaN
# 4     https://www.environment.gov.au/cgi-bin/sprat/p...            NaN
# ...                                                 ...            ...
# 1394  https://www.environment.gov.au/cgi-bin/sprat/p...  Velvet Zieria
# 1395  https://www.environment.gov.au/cgi-bin/sprat/p...            NaN
# 1396  https://www.environment.gov.au/cgi-bin/sprat/p...            NaN
# 1397  https://www.environment.gov.au/cgi-bin/sprat/p...   Warty Zieria
# 1398  https://www.environment.gov.au/cgi-bin/sprat/p...            NaN
#
#       Effective      Status Genus, species (subspecies, population).1
# 0    2000-07-16     Extinct                           Acacia kingiana
# 1    2000-07-16     Extinct                        Acacia prismifolia
# 2    2000-07-16     Extinct                       Acianthus ledwardii
# 3    2000-07-16     Extinct       Amperea xiphoclada var. pedicellata
# 4    2000-07-16     Extinct                        Amphibromus whitei
# ...         ...         ...                                       ...
# 1394 2000-07-16  Vulnerable                            Zieria murphyi
# 1395 2000-07-16  Vulnerable                            Zieria obovata
# 1396 2000-07-16  Vulnerable                           Zieria rimulosa
# 1397 2000-07-16  Vulnerable                        Zieria tuberculata
# 1398 2000-07-16  Vulnerable                          Zieria verrucosa
#
# [1399 rows x 5 columns]

# %%
#rename the DwC terms
data = data.rename(columns=
{
'Genus, species (subspecies, population)':'scientificNameLink',
'Genus, species (subspecies, population).1':'scientificName',
'Common Name':'vernacularName',
'Status':'status',
'Effective':'effectiveDate'
})

# %%
data['sourceStatus'] = data['status'].copy()

# %%
data['status'] = data['status'].str.split('(').str[0]

# %%
data['effectiveDate'] = pd.to_datetime(data['effectiveDate'],dayfirst=True).dt.strftime("%Y-%m-%d")

# %%
data
# Out:
#                                      scientificNameLink vernacularName  \
# 0     https://www.environment.gov.au/cgi-bin/sprat/p...            NaN
# 1     https://www.environment.gov.au/cgi-bin/sprat/p...  Diels' Wattle
# 2     https://www.environment.gov.au/cgi-bin/sprat/p...            NaN
# 3     https://www.environment.gov.au/cgi-bin/sprat/p...            NaN
# 4     https://www.environment.gov.au/cgi-bin/sprat/p...            NaN
# ...                                                 ...            ...
# 1394  https://www.environment.gov.au/cgi-bin/sprat/p...  Velvet Zieria
# 1395  https://www.environment.gov.au/cgi-bin/sprat/p...            NaN
# 1396  https://www.environment.gov.au/cgi-bin/sprat/p...            NaN
# 1397  https://www.environment.gov.au/cgi-bin/sprat/p...   Warty Zieria
# 1398  https://www.environment.gov.au/cgi-bin/sprat/p...            NaN
#
#      effectiveDate      status                       scientificName  \
# 0       2000-07-16     Extinct                      Acacia kingiana
# 1       2000-07-16     Extinct                   Acacia prismifolia
# 2       2000-07-16     Extinct                  Acianthus ledwardii
# 3       2000-07-16     Extinct  Amperea xiphoclada var. pedicellata
# 4       2000-07-16     Extinct                   Amphibromus whitei
# ...            ...         ...                                  ...
# 1394    2000-07-16  Vulnerable                       Zieria murphyi
# 1395    2000-07-16  Vulnerable                       Zieria obovata
# 1396    2000-07-16  Vulnerable                      Zieria rimulosa
# 1397    2000-07-16  Vulnerable                   Zieria tuberculata
# 1398    2000-07-16  Vulnerable                     Zieria verrucosa
#
#      sourceStatus
# 0         Extinct
# 1         Extinct
# 2         Extinct
# 3         Extinct
# 4         Extinct
# ...           ...
# 1394   Vulnerable
# 1395   Vulnerable
# 1396   Vulnerable
# 1397   Vulnerable
# 1398   Vulnerable
#
# [1399 rows x 6 columns]

# %%
data['status'].count()
# Out:
# 1399

# %%
data['taxonRemark'] = 'Flora'
data
# Out:
#                                      scientificNameLink vernacularName  \
# 0     https://www.environment.gov.au/cgi-bin/sprat/p...            NaN
# 1     https://www.environment.gov.au/cgi-bin/sprat/p...  Diels' Wattle
# 2     https://www.environment.gov.au/cgi-bin/sprat/p...            NaN
# 3     https://www.environment.gov.au/cgi-bin/sprat/p...            NaN
# 4     https://www.environment.gov.au/cgi-bin/sprat/p...            NaN
# ...                                                 ...            ...
# 1394  https://www.environment.gov.au/cgi-bin/sprat/p...  Velvet Zieria
# 1395  https://www.environment.gov.au/cgi-bin/sprat/p...            NaN
# 1396  https://www.environment.gov.au/cgi-bin/sprat/p...            NaN
# 1397  https://www.environment.gov.au/cgi-bin/sprat/p...   Warty Zieria
# 1398  https://www.environment.gov.au/cgi-bin/sprat/p...            NaN
#
#      effectiveDate      status                       scientificName  \
# 0       2000-07-16     Extinct                      Acacia kingiana
# 1       2000-07-16     Extinct                   Acacia prismifolia
# 2       2000-07-16     Extinct                  Acianthus ledwardii
# 3       2000-07-16     Extinct  Amperea xiphoclada var. pedicellata
# 4       2000-07-16     Extinct                   Amphibromus whitei
# ...            ...         ...                                  ...
# 1394    2000-07-16  Vulnerable                       Zieria murphyi
# 1395    2000-07-16  Vulnerable                       Zieria obovata
# 1396    2000-07-16  Vulnerable                      Zieria rimulosa
# 1397    2000-07-16  Vulnerable                   Zieria tuberculata
# 1398    2000-07-16  Vulnerable                     Zieria verrucosa
#
#      sourceStatus taxonRemark
# 0         Extinct       Flora
# 1         Extinct       Flora
# 2         Extinct       Flora
# 3         Extinct       Flora
# 4         Extinct       Flora
# ...           ...         ...
# 1394   Vulnerable       Flora
# 1395   Vulnerable       Flora
# 1396   Vulnerable       Flora
# 1397   Vulnerable       Flora
# 1398   Vulnerable       Flora
#
# [1399 rows x 7 columns]

# %%
data.to_excel('/Users/cha801/Documents/UpdateLists/v1/EPBCfinal-Flora.xlsx',index = False)
